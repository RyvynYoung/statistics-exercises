# %%
import pandas as pd

# %%
pd.read_json(r'metadata.json')
# Out:
#                           id  identifier                       persistentUrl  \
# UNF                  2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# citation             2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# contactForAccess     2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# createTime           2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# datasetId            2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# datasetPersistentId  2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# fileAccessRequest    2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# files                2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# id                   2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# lastUpdateTime       2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# license              2961641  DVN/KFT8EZ  https://doi.org/10.7910/DVN/KFT8EZ
# ...
